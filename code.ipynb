# %%
import requests
import bs4
import pandas as pd

# %%
title=[] #先列出想要爬取的欄位
company=[]
region=[]
experience_requirement=[]
education_requirement=[]
job_description=[]
salary=[]
job_update_date=[]
job_url=[]
list1=[region,experience_requirement,education_requirement]
for i in range(1,16): #先人工搜尋有幾頁 (理賠人員職缺共有16頁)
    page=i
    url =f"https://www.104.com.tw/jobs/search/?ro=0&kwop=1&keyword=理賠&expansionType=area,spec,com,job,wf,wktm&order=15&asc=0&page={page}&mode=s&langFlag=0&langStatus=0&recommendJob=1&hotJob=1"
    html_file=requests.get(url)
    ObjSoup=bs4.BeautifulSoup(html_file.text,'html')
    jobs=ObjSoup.find_all('article',class_="b-block--top-bord job-list-item b-clearfix js-job-item")
    for job in jobs:
        title.append(job.get("data-job-name"))
        company.append(job.get("data-cust-name"))  
        for i in range(3):
            list1[i].append(job.find("ul",class_="b-list-inline b-clearfix job-list-intro b-content").find_all("li")[i].text)
        job_description.append(job.find("p",class_="job-list-item__info b-clearfix b-content").text)
        try:
            salary.append(job.find("div",class_="job-list-tag").find("a").text)
        except:
            salary.append("none")
        job_update_date.append(job.find("div",class_="b-block__left").find("span").text)
        job_url.append("https:"+job.find("div",class_="b-block__left").find("a").get("href"))

# %%
df = pd.DataFrame({'title': title, 'company': company, 'region': region, 
                   'experience_requirement': experience_requirement, 'education_requirement': education_requirement, 
                   'job_description': job_description, 'salary': salary, 'job_update_date': job_update_date,
                   'url': job_url})

# %%
df
# Out:
#                     title                   company  region  \
# 0                 企業險理賠人員            中國信託產物保險股份有限公司  台中市西屯區
# 1               理賠人員(理賠處)          全球人壽保險股份有限公司_總公司  台北市信義區
# 2               理賠專員(新莊廠)  Master Win集團_馬自達企業股份有限公司  新北市新莊區
# 3                  理賠電訪人員              和泰產物保險股份有限公司  台北市中山區
# 4          理賠人員(高雄理賠處理賠科)            旺旺友聯產物保險股份有限公司  高雄市前金區
# ..                    ...                       ...     ...
# 293  理賠人員(台南新營)-汽修 法律專業者佳     三井住友海上集團_明台產物保險股份有限公司  台南市新營區
# 294  軟體工程師(應用系統一部/理賠系統一科)         富邦人壽保險股份有限公司(總公司)  台北市內湖區
# 295  理賠人員(台南永康)-汽修 法律專業者佳     三井住友海上集團_明台產物保險股份有限公司  台南市永康區
# 296                理賠企劃人員              和泰產物保險股份有限公司  台北市中山區
# 297    理賠人員(台南)-汽修 法律專業者佳     三井住友海上集團_明台產物保險股份有限公司  台南市安平區
#
#     experience_requirement education_requirement  \
# 0                     3年以上                    大學
# 1                     1年以上                    專科
# 2                     2年以上                    高中
# 3                     經歷不拘                    專科
# 4                     1年以上                    大學
# ..                     ...                   ...
# 293                   經歷不拘                    大學
# 294                   3年以上                    專科
# 295                   經歷不拘                    大學
# 296                   2年以上                    大學
# 297                   經歷不拘                    大學
#
#                                        job_description            salary  \
# 0    1.負責責任險/火險/傷害險理賠案件審。\n2.保戶及業務人員理賠諮詢。\n3.爭議案件處理...  月薪30,000~45,000元
# 1    1. 理賠案件(non-clean、團險)之審查 \n2. 理賠案件之答詢\n3. 理賠申訴...       月薪32,500元以上
# 2    1.保險理賠行政作業\n2.一般車輛鈑烤估價\n3.事故車輛保險理賠作業\n4.鈑烤維修進度...  月薪36,000~60,000元
# 3          1.理賠電話客服(非業務員)。\n2.協助客戶申請保險理賠。\n3.理賠行政相關業務。  月薪28,000~40,000元
# 4    1.辦理企業險、旅平險及傷害險等理賠相關工作。\n2.了解保險法及民法損害賠償基本概念者佳。...  月薪32,000~50,000元
# ..                                                 ...               ...
# 293  1. 執行理賠案件之電腦受理。\n2. 審查保險契約內容。\n3. 協助客戶進行現場處理、和...  月薪29,600~50,000元
# 294                          1. 理賠系統維運。\n2. 理賠需求規劃與開發。          員工24000人
# 295  1. 執行理賠案件之電腦受理。\n2. 審查保險契約內容。\n3. 協助客戶進行現場處理、和...  月薪29,600~50,000元
# 296  1. 相關策略規劃、制度之擬定\n2. 相關作業流程之檢視及規劃及系統功能設計\n3. 報表...  月薪28,000~40,000元
# 297  1. 執行理賠案件之電腦受理。\n2. 審查保險契約內容。\n3. 協助客戶進行現場處理、和...  月薪29,600~50,000元
#
#           job_update_date                                                url
# 0    4/25                  https://www.104.com.tw/job/7z42n?jobsource=jol...
# 1    4/27                  https://www.104.com.tw/job/7gfhr?jobsource=jol...
# 2    4/24                  https://www.104.com.tw/job/7m9r7?jobsource=jol...
# 3    4/26                  https://www.104.com.tw/job/7ylfc?jobsource=jol...
# 4    4/27                  https://www.104.com.tw/job/7qijc?jobsource=jol...
# ..                    ...                                                ...
# 293  4/21                  https://www.104.com.tw/job/6rreo?jobsource=jol...
# 294  4/20                  https://www.104.com.tw/job/7cism?jobsource=jol...
# 295  4/21                  https://www.104.com.tw/job/6rrel?jobsource=jol...
# 296  4/25                  https://www.104.com.tw/job/6cmxd?jobsource=jol...
# 297  4/21                  https://www.104.com.tw/job/3oehn?jobsource=jol...
#
# [298 rows x 9 columns]

# %%
file_name="理賠人員職缺.xlsx"
df.to_excel(file_name, index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 file_name="理賠人員職缺.xlsx"
# ----> 2 df.to_excel(file_name, index=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\excel.py:944, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     940     need_save = False
#     941 else:
#     942     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     943     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 944     writer = ExcelWriter(  # type: ignore[abstract]
#     945         writer, engine=engine, storage_options=storage_options
#     946     )
#     947     need_save = True
#     949 try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_openpyxl.py:60, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      56 from openpyxl.workbook import Workbook
#      58 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 60 super().__init__(
#      61     path,
#      62     mode=mode,
#      63     storage_options=storage_options,
#      64     if_sheet_exists=if_sheet_exists,
#      65     engine_kwargs=engine_kwargs,
#      66 )
#      68 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      69 # the file and later write to it
#      70 if "r+" in self._mode:  # Load from existing workbook
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1313, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1309 self._handles = IOHandles(
#    1310     cast(IO[bytes], path), compression={"compression": None}
#    1311 )
#    1312 if not isinstance(path, ExcelWriter):
# -> 1313     self._handles = get_handle(
#    1314         path, mode, storage_options=storage_options, is_text=False
#    1315     )
#    1316 self._cur_sheet = None
#    1318 if date_format is None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: '理賠人員職缺.xlsx'
